# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

df = pd.read_csv("../dataset/abalone.csv",index_col=0)

# %%
# 데이터 확인
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# 단변량 시퀀스를 여러 샘플로 분할하는 함수
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# 결측치 확인
(df == 0).sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            2
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
# 결측치 제거
# Outcome 열을 제외한 나머지 열에서 0이 포함된 행을 제거
df = df[(df!= 0).all(axis=1)]

# 결과 출력
print(df.shape)  # 0 값이 제거된 후의 데이터 크기 확인
# Out:
# (4175, 9)

# %%
# Sex 값을 F -> 0, M -> 1로 변환
df['Sex'] = df['Sex'].replace({'F': 0, 'M': 1, 'I':2})
# Out:
# /var/folders/nr/9d9y7mfn50b3sc_ncv28vstc0000gn/T/ipykernel_19842/377919716.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sex'] = df['Sex'].replace({'F': 0, 'M': 1, 'I':2})
# /var/folders/nr/9d9y7mfn50b3sc_ncv28vstc0000gn/T/ipykernel_19842/377919716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex'] = df['Sex'].replace({'F': 0, 'M': 1, 'I':2})

# %%
X = df.drop('Rings', axis=1).values
y = df['Rings'].values
y_adjusted = y - 1 # Rings 값이 1부터 시작하므로 0으로 조정

# %%
# 데이터 정규화
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 시퀀스 길이 설정
n_steps = 3  # 시퀀스 길이 (조정 가능)

# 시퀀스 데이터로 분할
X_seq, y_seq = split_sequence(y_adjusted, n_steps)

# %%
# 학습용 데이터셋 분할
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# LSTM 입력에 맞게 차원 확장
X_train = X_train[:, :, np.newaxis]
X_test = X_test[:, :, np.newaxis]

num_classes = len(np.unique(y_train)) +1

# LSTM 모델 구축
model = Sequential()
model.add(LSTM(64, input_shape=(n_steps, 1), return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(32))
model.add(Dropout(0.3))
model.add(Dense(1))  # 출력 레이어, 회귀이므로 1

# 모델 컴파일
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 모델 학습
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5320 - val_loss: 7.5883
# Epoch 2/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8869 - val_loss: 7.6290
# Epoch 3/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4164 - val_loss: 7.5903
# Epoch 4/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3128 - val_loss: 7.6411
# Epoch 5/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0379 - val_loss: 7.5935
# Epoch 6/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1327 - val_loss: 7.8561
# Epoch 7/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5445 - val_loss: 7.5603
# Epoch 8/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4639 - val_loss: 7.7142
# Epoch 9/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3241 - val_loss: 7.6751
# Epoch 10/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4928 - val_loss: 7.6068
# Epoch 11/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6013 - val_loss: 7.7121
# Epoch 12/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3179 - val_loss: 7.7081
# Epoch 13/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1487 - val_loss: 7.6251
# Epoch 14/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6097 - val_loss: 7.6072
# Epoch 15/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5835 - val_loss: 8.0164
# Epoch 16/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5384 - val_loss: 7.6761
# Epoch 17/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7698 - val_loss: 7.7893
# Epoch 18/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3060 - val_loss: 7.6141
# Epoch 19/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5437 - val_loss: 7.6698
# Epoch 20/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3078 - val_loss: 7.6412
# Epoch 21/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7794 - val_loss: 7.7940
# Epoch 22/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5749 - val_loss: 7.7750
# Epoch 23/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9008 - val_loss: 7.7459
# Epoch 24/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3209 - val_loss: 7.6581
# Epoch 25/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0145 - val_loss: 7.5992
# Epoch 26/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8814 - val_loss: 7.6184
# Epoch 27/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8235 - val_loss: 7.7016
# Epoch 28/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9859 - val_loss: 7.6379
# Epoch 29/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2208 - val_loss: 7.6553
# Epoch 30/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6381 - val_loss: 7.6785

# %%
# 모델 평가
loss = model.evaluate(X_test, y_test)
print(f'Test Loss (MSE): {loss}')
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 6.5536
# Test Loss (MSE): 6.9541096687316895
